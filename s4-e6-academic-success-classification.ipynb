# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import xgboost as xgb

# %%
train_df = pd.read_csv("/kaggle/input/playground-series-s4e6/train.csv")
test_df = pd.read_csv("/kaggle/input/playground-series-s4e6/test.csv")

# %% [markdown]
# # Basic EDA

# %%
train_df.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# 2                           137.0            1                       3  ...
# 3                           131.0            1                      19  ...
# 4                           132.0            1                      19  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    6
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    8
# 4                                    0                                    7
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       7
# 1                                       9
# 2                                       0
# 3                                      11
# 4                                      12
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    6                         12.428571
# 1                                    0                          0.000000
# 2                                    0                          0.000000
# 3                                    7                         12.820000
# 4                                    6                         12.933333
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               11.1
# 1                                               0               11.1
# 2                                               0               16.2
# 3                                               0               11.1
# 4                                               0                7.6
#
#    Inflation rate   GDP    Target
# 0             0.6  2.02  Graduate
# 1             0.6  2.02   Dropout
# 2             0.3 -0.92   Dropout
# 3             0.6  2.02  Enrolled
# 4             2.6  0.32  Graduate
#
# [5 rows x 38 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
#  9   Mother's qualification                          76518 non-null  int64
#  10  Father's qualification                          76518 non-null  int64
#  11  Mother's occupation                             76518 non-null  int64
#  12  Father's occupation                             76518 non-null  int64
#  13  Admission grade                                 76518 non-null  float64
#  14  Displaced                                       76518 non-null  int64
#  15  Educational special needs                       76518 non-null  int64
#  16  Debtor                                          76518 non-null  int64
#  17  Tuition fees up to date                         76518 non-null  int64
#  18  Gender                                          76518 non-null  int64
#  19  Scholarship holder                              76518 non-null  int64
#  20  Age at enrollment                               76518 non-null  int64
#  21  International                                   76518 non-null  int64
#  22  Curricular units 1st sem (credited)             76518 non-null  int64
#  23  Curricular units 1st sem (enrolled)             76518 non-null  int64
#  24  Curricular units 1st sem (evaluations)          76518 non-null  int64
#  25  Curricular units 1st sem (approved)             76518 non-null  int64
#  26  Curricular units 1st sem (grade)                76518 non-null  float64
#  27  Curricular units 1st sem (without evaluations)  76518 non-null  int64
#  28  Curricular units 2nd sem (credited)             76518 non-null  int64
#  29  Curricular units 2nd sem (enrolled)             76518 non-null  int64
#  30  Curricular units 2nd sem (evaluations)          76518 non-null  int64
#  31  Curricular units 2nd sem (approved)             76518 non-null  int64
#  32  Curricular units 2nd sem (grade)                76518 non-null  float64
#  33  Curricular units 2nd sem (without evaluations)  76518 non-null  int64
#  34  Unemployment rate                               76518 non-null  float64
#  35  Inflation rate                                  76518 non-null  float64
#  36  GDP                                             76518 non-null  float64
#  37  Target                                          76518 non-null  object
# dtypes: float64(7), int64(30), object(1)
# memory usage: 22.2+ MB

# %%
train_df.isna().sum()
# Out:
# id                                                0
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
X = train_df.drop(columns = ['Target'])
y = train_df['Target']

# %% [markdown]
# # Label Encoding

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# # XGB Classifier

# %%
model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# %%
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# # Base Model Evaluation

# %%
y_val_pred = model.predict(X_val)
accuracy = accuracy_score(y_val, y_val_pred)
c_report = classification_report(y_val, y_val_pred)
print(f"Validation Accuracy: {accuracy}")
print(f"Classification Report: {c_report}")
# Out:
# Validation Accuracy: 0.8299137480397282
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      5028
#            1       0.65      0.61      0.63      3017
#            2       0.86      0.92      0.89      7259
#
#     accuracy                           0.83     15304
#    macro avg       0.80      0.79      0.79     15304
# weighted avg       0.83      0.83      0.83     15304

# %% [markdown]
# # Hyperparameter Tuning

# %%
from scipy.stats import uniform, randint

param_dist = {
    'n_estimators': randint(50, 200),
    'learning_rate': uniform(0.01, 0.3),
    'max_depth': randint(3, 10),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4)
}

# %%
xg_class_cv = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# %%
random_search = RandomizedSearchCV(estimator=xg_class_cv, param_distributions=param_dist, n_iter=50, cv=3, n_jobs=-1, verbose=2, random_state=42)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='logloss',
#                                            feature_types=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning...
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7a8e2aa6da20>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7a8e2aa6fb20>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7a8e2aa6e5c0>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7a8e2aa6f220>},
#                    random_state=42, verbose=2)

# %%
best_model = random_search.best_estimator_

# %% [markdown]
# # Tuned Model Evaluation

# %%
y_val_pred = best_model.predict(X_val)
accuracy = accuracy_score(y_val, y_val_pred)
c_report = classification_report(y_val, y_val_pred)
print(f"Validation Accuracy: {accuracy}")
print(f"Classification report: {c_report}")
# Out:
# Validation Accuracy: 0.8336382645060115
# Classification report:               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.87      5028
#            1       0.66      0.62      0.64      3017
#            2       0.86      0.93      0.89      7259
#
#     accuracy                           0.83     15304
#    macro avg       0.81      0.79      0.80     15304
# weighted avg       0.83      0.83      0.83     15304

# %% [markdown]
# # Predictions on Test Set

# %%
test_predictions_encoded = best_model.predict(test_df)

# %%
test_predictions = label_encoder.inverse_transform(test_predictions_encoded)

# %%
submission_df = pd.DataFrame({
    'id': test_df['id'],
    'Target': test_predictions
})

# %%
submission_df.to_csv('submission.csv', index=False)

# %%
submission_df
# Out:
#            id    Target
# 0       76518   Dropout
# 1       76519  Graduate
# 2       76520  Graduate
# 3       76521  Enrolled
# 4       76522  Enrolled
# ...       ...       ...
# 51007  127525   Dropout
# 51008  127526   Dropout
# 51009  127527   Dropout
# 51010  127528   Dropout
# 51011  127529   Dropout
#
# [51012 rows x 2 columns]
# [CV] END colsample_bytree=0.6624074561769746, learning_rate=0.05679835610086079, max_depth=5, n_estimators=137, subsample=0.7334834444556088; total time=   9.4s
# [CV] END colsample_bytree=0.6571467271687763, learning_rate=0.20526654188465587, max_depth=7, n_estimators=51, subsample=0.8887995089067299; total time=   4.6s
# [CV] END colsample_bytree=0.9754210836063001, learning_rate=0.010233629752304298, max_depth=6, n_estimators=70, subsample=0.8469926038510867; total time=   6.3s
# [CV] END colsample_bytree=0.8446612641953124, learning_rate=0.012119891565915222, max_depth=3, n_estimators=98, subsample=0.8099098641033556; total time=   5.3s
# [CV] END colsample_bytree=0.7599443886861021, learning_rate=0.023999698964084628, max_depth=6, n_estimators=64, subsample=0.7824279936868144; total time=   5.3s
# [CV] END colsample_bytree=0.9439761626945282, learning_rate=0.2140922615763339, max_depth=3, n_estimators=67, subsample=0.9795542149013333; total time=   3.6s
# [CV] END colsample_bytree=0.9439761626945282, learning_rate=0.2140922615763339, max_depth=3, n_estimators=67, subsample=0.9795542149013333; total time=   3.7s
# [CV] END colsample_bytree=0.9439761626945282, learning_rate=0.2140922615763339, max_depth=3, n_estimators=67, subsample=0.9795542149013333; total time=   3.6s
# [CV] END colsample_bytree=0.9862528132298237, learning_rate=0.2525192044349383, max_depth=3, n_estimators=139, subsample=0.6390688456025535; total time=   7.2s
# [CV] END colsample_bytree=0.8736932106048627, learning_rate=0.1420457481218804, max_depth=9, n_estimators=57, subsample=0.6137554084460873; total time=   7.0s
# [CV] END colsample_bytree=0.6831766651472755, learning_rate=0.18031009834599745, max_depth=7, n_estimators=195, subsample=0.9100531293444458; total time=  15.4s
# [CV] END colsample_bytree=0.9757995766256756, learning_rate=0.27844820512829466, max_depth=8, n_estimators=144, subsample=0.9687496940092467; total time=  14.3s
# [CV] END colsample_bytree=0.718509402281633, learning_rate=0.05958008171890075, max_depth=3, n_estimators=120, subsample=0.7693605922825478; total time=   6.4s
# [CV] END colsample_bytree=0.7579526072702278, learning_rate=0.09804645241541143, max_depth=9, n_estimators=188, subsample=0.679536961635522; total time=  22.4s
# [CV] END colsample_bytree=0.8604308102007778, learning_rate=0.28448790266313423, max_depth=3, n_estimators=121, subsample=0.7797802696552814; total time=   5.9s
# [CV] END colsample_bytree=0.6381640465961645, learning_rate=0.1212454756594799, max_depth=8, n_estimators=86, subsample=0.8918424713352255; total time=   8.5s
# [CV] END colsample_bytree=0.9395655297064336, learning_rate=0.22651885634946198, max_depth=9, n_estimators=191, subsample=0.7975182385457563; total time=  22.8s
# [CV] END colsample_bytree=0.8090931317527976, learning_rate=0.13826230550756488, max_depth=4, n_estimators=173, subsample=0.6431565707973218; total time=   9.6s
# [CV] END colsample_bytree=0.6557325817623503, learning_rate=0.1913252137833452, max_depth=9, n_estimators=78, subsample=0.6915192661966489; total time=   8.8s
# [CV] END colsample_bytree=0.6307919639315172, learning_rate=0.0969254358741304, max_depth=8, n_estimators=77, subsample=0.9718790609370292; total time=   8.5s
# [CV] END colsample_bytree=0.9232481518257668, learning_rate=0.20002112695312704, max_depth=8, n_estimators=77, subsample=0.9214688307596458; total time=   7.7s
# [CV] END colsample_bytree=0.9584365199693973, learning_rate=0.10540104249155915, max_depth=3, n_estimators=178, subsample=0.6911740650167767; total time=   8.8s
# [CV] END colsample_bytree=0.7708431154505025, learning_rate=0.25540442977674793, max_depth=3, n_estimators=52, subsample=0.6027808522124762; total time=   2.9s
# [CV] END colsample_bytree=0.8042989210310263, learning_rate=0.1352233009446337, max_depth=7, n_estimators=100, subsample=0.7077649335194086; total time=   8.6s
# [CV] END colsample_bytree=0.7015661655737379, learning_rate=0.08406281885158035, max_depth=9, n_estimators=179, subsample=0.8849082359697769; total time=  20.2s
# [CV] END colsample_bytree=0.6592347719813599, learning_rate=0.30932214551468257, max_depth=5, n_estimators=162, subsample=0.9906459823330611; total time=   9.3s
# [CV] END colsample_bytree=0.6579579488364892, learning_rate=0.1568358280832689, max_depth=8, n_estimators=117, subsample=0.632341330533086; total time=  11.5s
# [CV] END colsample_bytree=0.7478617824245618, learning_rate=0.08264798148322776, max_depth=8, n_estimators=73, subsample=0.7881202537784153; total time=   7.8s
# [CV] END colsample_bytree=0.9933692563579372, learning_rate=0.12964733273336593, max_depth=9, n_estimators=193, subsample=0.9341209982356952; total time=  22.6s
# [CV] END colsample_bytree=0.6384706204365683, learning_rate=0.2921569793468812, max_depth=9, n_estimators=131, subsample=0.9350840423629312; total time=  13.7s
# [CV] END colsample_bytree=0.8702760468157122, learning_rate=0.23056483577223164, max_depth=4, n_estimators=91, subsample=0.7031766510860622; total time=   5.2s
# [CV] END colsample_bytree=0.8639936184136716, learning_rate=0.25516666006036476, max_depth=3, n_estimators=109, subsample=0.7043316699321636; total time=   5.4s
# [CV] END colsample_bytree=0.9985014799031697, learning_rate=0.2996258053866381, max_depth=7, n_estimators=86, subsample=0.9530545372757359; total time=   8.0s
# [CV] END colsample_bytree=0.6754828433365517, learning_rate=0.09366140577765455, max_depth=5, n_estimators=97, subsample=0.9386644568953224; total time=   6.4s
# [CV] END colsample_bytree=0.6646514856378455, learning_rate=0.2795662565581238, max_depth=6, n_estimators=161, subsample=0.6405886171464128; total time=  11.3s
# [CV] END colsample_bytree=0.8654007076432223, learning_rate=0.011518475153865606, max_depth=8, n_estimators=131, subsample=0.7942455014344907; total time=  15.1s
# [CV] END colsample_bytree=0.7793696571944989, learning_rate=0.3083372387832462, max_depth=6, n_estimators=117, subsample=0.69489963499872; total time=   8.5s
# [CV] END colsample_bytree=0.749816047538945, learning_rate=0.2952142919229748, max_depth=5, n_estimators=121, subsample=0.8394633936788146; total time=   7.5s
# [CV] END colsample_bytree=0.6624074561769746, learning_rate=0.05679835610086079, max_depth=5, n_estimators=137, subsample=0.7334834444556088; total time=  10.1s
# [CV] END colsample_bytree=0.9754210836063001, learning_rate=0.010233629752304298, max_depth=6, n_estimators=70, subsample=0.8469926038510867; total time=   5.8s
# [CV] END colsample_bytree=0.7599443886861021, learning_rate=0.023999698964084628, max_depth=6, n_estimators=64, subsample=0.7824279936868144; total time=   5.3s
# [CV] END colsample_bytree=0.9140703845572055, learning_rate=0.06990213464750791, max_depth=9, n_estimators=113, subsample=0.786705157299192; total time=  14.5s
# [CV] END colsample_bytree=0.8736932106048627, learning_rate=0.1420457481218804, max_depth=9, n_estimators=57, subsample=0.6137554084460873; total time=   7.7s
# [CV] END colsample_bytree=0.9637281608315128, learning_rate=0.08763399448000507, max_depth=6, n_estimators=51, subsample=0.7700623497964979; total time=   4.5s
# [CV] END colsample_bytree=0.6831766651472755, learning_rate=0.18031009834599745, max_depth=7, n_estimators=195, subsample=0.9100531293444458; total time=  15.5s
# [CV] END colsample_bytree=0.9757995766256756, learning_rate=0.27844820512829466, max_depth=8, n_estimators=144, subsample=0.9687496940092467; total time=  14.0s
# [CV] END colsample_bytree=0.8989280440549523, learning_rate=0.17190763971672393, max_depth=4, n_estimators=173, subsample=0.7103996728090174; total time=   9.4s
# [CV] END colsample_bytree=0.7579526072702278, learning_rate=0.09804645241541143, max_depth=9, n_estimators=188, subsample=0.679536961635522; total time=  22.5s
# [CV] END colsample_bytree=0.6381640465961645, learning_rate=0.1212454756594799, max_depth=8, n_estimators=86, subsample=0.8918424713352255; total time=   8.4s
# [CV] END colsample_bytree=0.8550229885420852, learning_rate=0.27616382277289797, max_depth=3, n_estimators=150, subsample=0.9886848381556415; total time=   7.1s
# [CV] END colsample_bytree=0.8090931317527976, learning_rate=0.13826230550756488, max_depth=4, n_estimators=173, subsample=0.6431565707973218; total time=   9.7s
# [CV] END colsample_bytree=0.8090931317527976, learning_rate=0.13826230550756488, max_depth=4, n_estimators=173, subsample=0.6431565707973218; total time=   9.9s
# [CV] END colsample_bytree=0.6125716742746937, learning_rate=0.20092312337913412, max_depth=6, n_estimators=145, subsample=0.878206434570451; total time=   9.8s
# [CV] END colsample_bytree=0.6557325817623503, learning_rate=0.1913252137833452, max_depth=9, n_estimators=78, subsample=0.6915192661966489; total time=   8.6s
# [CV] END colsample_bytree=0.6307919639315172, learning_rate=0.0969254358741304, max_depth=8, n_estimators=77, subsample=0.9718790609370292; total time=   8.4s
# [CV] END colsample_bytree=0.6746280235544143, learning_rate=0.2777676995469933, max_depth=5, n_estimators=177, subsample=0.922976062065625; total time=  10.4s
# [CV] END colsample_bytree=0.9584365199693973, learning_rate=0.10540104249155915, max_depth=3, n_estimators=178, subsample=0.6911740650167767; total time=   8.8s
# [CV] END colsample_bytree=0.6976502088991097, learning_rate=0.06048731265187917, max_depth=3, n_estimators=162, subsample=0.6259568988435926; total time=   8.3s
# [CV] END colsample_bytree=0.6976502088991097, learning_rate=0.06048731265187917, max_depth=3, n_estimators=162, subsample=0.6259568988435926; total time=   8.9s
# [CV] END colsample_bytree=0.6592347719813599, learning_rate=0.30932214551468257, max_depth=5, n_estimators=162, subsample=0.9906459823330611; total time=   9.4s
# [CV] END colsample_bytree=0.6592347719813599, learning_rate=0.30932214551468257, max_depth=5, n_estimators=162, subsample=0.9906459823330611; total time=   9.2s
# [CV] END colsample_bytree=0.7644148053272926, learning_rate=0.019915219870164515, max_depth=3, n_estimators=178, subsample=0.695824756266789; total time=  10.0s
# [CV] END colsample_bytree=0.7478617824245618, learning_rate=0.08264798148322776, max_depth=8, n_estimators=73, subsample=0.7881202537784153; total time=   7.8s
# [CV] END colsample_bytree=0.9933692563579372, learning_rate=0.12964733273336593, max_depth=9, n_estimators=193, subsample=0.9341209982356952; total time=  22.3s
# [CV] END colsample_bytree=0.871025744736913, learning_rate=0.014976348678356847, max_depth=5, n_estimators=196, subsample=0.7394663949166917; total time=  14.2s
# [CV] END colsample_bytree=0.6384706204365683, learning_rate=0.2921569793468812, max_depth=9, n_estimators=131, subsample=0.9350840423629312; total time=  13.6s
# [CV] END colsample_bytree=0.8639936184136716, learning_rate=0.25516666006036476, max_depth=3, n_estimators=109, subsample=0.7043316699321636; total time=   6.1s
# [CV] END colsample_bytree=0.6754828433365517, learning_rate=0.09366140577765455, max_depth=5, n_estimators=97, subsample=0.9386644568953224; total time=   6.5s
# [CV] END colsample_bytree=0.942529716751237, learning_rate=0.13135243813665703, max_depth=3, n_estimators=165, subsample=0.6336559859980195; total time=   8.2s
# [CV] END colsample_bytree=0.6646514856378455, learning_rate=0.2795662565581238, max_depth=6, n_estimators=161, subsample=0.6405886171464128; total time=  11.3s
# [CV] END colsample_bytree=0.7793696571944989, learning_rate=0.3083372387832462, max_depth=6, n_estimators=117, subsample=0.69489963499872; total time=   9.0s
# [CV] END colsample_bytree=0.7301598792637071, learning_rate=0.23394742153540724, max_depth=9, n_estimators=194, subsample=0.7232243167409557; total time=  20.0s
# [CV] END colsample_bytree=0.749816047538945, learning_rate=0.2952142919229748, max_depth=5, n_estimators=121, subsample=0.8394633936788146; total time=   7.6s
# [CV] END colsample_bytree=0.6571467271687763, learning_rate=0.20526654188465587, max_depth=7, n_estimators=51, subsample=0.8887995089067299; total time=   4.8s
# [CV] END colsample_bytree=0.6571467271687763, learning_rate=0.20526654188465587, max_depth=7, n_estimators=51, subsample=0.8887995089067299; total time=   4.9s
# [CV] END colsample_bytree=0.9754210836063001, learning_rate=0.010233629752304298, max_depth=6, n_estimators=70, subsample=0.8469926038510867; total time=   5.9s
# [CV] END colsample_bytree=0.7599443886861021, learning_rate=0.023999698964084628, max_depth=6, n_estimators=64, subsample=0.7824279936868144; total time=   5.3s
# [CV] END colsample_bytree=0.9140703845572055, learning_rate=0.06990213464750791, max_depth=9, n_estimators=113, subsample=0.786705157299192; total time=  14.6s
# [CV] END colsample_bytree=0.9862528132298237, learning_rate=0.2525192044349383, max_depth=3, n_estimators=139, subsample=0.6390688456025535; total time=   7.4s
# [CV] END colsample_bytree=0.9637281608315128, learning_rate=0.08763399448000507, max_depth=6, n_estimators=51, subsample=0.7700623497964979; total time=   4.4s
# [CV] END colsample_bytree=0.9637281608315128, learning_rate=0.08763399448000507, max_depth=6, n_estimators=51, subsample=0.7700623497964979; total time=   4.4s
# [CV] END colsample_bytree=0.9757995766256756, learning_rate=0.27844820512829466, max_depth=8, n_estimators=144, subsample=0.9687496940092467; total time=  13.8s
# [CV] END colsample_bytree=0.6353970008207678, learning_rate=0.06879485872574355, max_depth=3, n_estimators=89, subsample=0.9378135394712606; total time=   4.8s
# [CV] END colsample_bytree=0.8989280440549523, learning_rate=0.17190763971672393, max_depth=4, n_estimators=173, subsample=0.7103996728090174; total time=   9.8s
# [CV] END colsample_bytree=0.718509402281633, learning_rate=0.05958008171890075, max_depth=3, n_estimators=120, subsample=0.7693605922825478; total time=   6.3s
# [CV] END colsample_bytree=0.7579526072702278, learning_rate=0.09804645241541143, max_depth=9, n_estimators=188, subsample=0.679536961635522; total time=  22.0s
# [CV] END colsample_bytree=0.8604308102007778, learning_rate=0.28448790266313423, max_depth=3, n_estimators=121, subsample=0.7797802696552814; total time=   6.0s
# [CV] END colsample_bytree=0.8550229885420852, learning_rate=0.27616382277289797, max_depth=3, n_estimators=150, subsample=0.9886848381556415; total time=   7.2s
# [CV] END colsample_bytree=0.9395655297064336, learning_rate=0.22651885634946198, max_depth=9, n_estimators=191, subsample=0.7975182385457563; total time=  22.5s
# [CV] END colsample_bytree=0.6125716742746937, learning_rate=0.20092312337913412, max_depth=6, n_estimators=145, subsample=0.878206434570451; total time=   9.9s
# [CV] END colsample_bytree=0.6557325817623503, learning_rate=0.1913252137833452, max_depth=9, n_estimators=78, subsample=0.6915192661966489; total time=   8.8s
# [CV] END colsample_bytree=0.9232481518257668, learning_rate=0.20002112695312704, max_depth=8, n_estimators=77, subsample=0.9214688307596458; total time=   8.2s
# [CV] END colsample_bytree=0.6746280235544143, learning_rate=0.2777676995469933, max_depth=5, n_estimators=177, subsample=0.922976062065625; total time=  10.4s
# [CV] END colsample_bytree=0.9584365199693973, learning_rate=0.10540104249155915, max_depth=3, n_estimators=178, subsample=0.6911740650167767; total time=   8.8s
# [CV] END colsample_bytree=0.8042989210310263, learning_rate=0.1352233009446337, max_depth=7, n_estimators=100, subsample=0.7077649335194086; total time=   8.5s
# [CV] END colsample_bytree=0.7015661655737379, learning_rate=0.08406281885158035, max_depth=9, n_estimators=179, subsample=0.8849082359697769; total time=  20.6s
# [CV] END colsample_bytree=0.7644148053272926, learning_rate=0.019915219870164515, max_depth=3, n_estimators=178, subsample=0.695824756266789; total time=   9.3s
# [CV] END colsample_bytree=0.6579579488364892, learning_rate=0.1568358280832689, max_depth=8, n_estimators=117, subsample=0.632341330533086; total time=  11.8s
# [CV] END colsample_bytree=0.7478617824245618, learning_rate=0.08264798148322776, max_depth=8, n_estimators=73, subsample=0.7881202537784153; total time=   7.7s
# [CV] END colsample_bytree=0.7283120259886944, learning_rate=0.06595555311995627, max_depth=7, n_estimators=52, subsample=0.8363571772752967; total time=   5.0s
# [CV] END colsample_bytree=0.7283120259886944, learning_rate=0.06595555311995627, max_depth=7, n_estimators=52, subsample=0.8363571772752967; total time=   5.0s
# [CV] END colsample_bytree=0.7283120259886944, learning_rate=0.06595555311995627, max_depth=7, n_estimators=52, subsample=0.8363571772752967; total time=   5.0s
# [CV] END colsample_bytree=0.871025744736913, learning_rate=0.014976348678356847, max_depth=5, n_estimators=196, subsample=0.7394663949166917; total time=  14.2s
# [CV] END colsample_bytree=0.6384706204365683, learning_rate=0.2921569793468812, max_depth=9, n_estimators=131, subsample=0.9350840423629312; total time=  13.9s
# [CV] END colsample_bytree=0.8639936184136716, learning_rate=0.25516666006036476, max_depth=3, n_estimators=109, subsample=0.7043316699321636; total time=   5.5s
# [CV] END colsample_bytree=0.9985014799031697, learning_rate=0.2996258053866381, max_depth=7, n_estimators=86, subsample=0.9530545372757359; total time=   7.7s
# [CV] END colsample_bytree=0.942529716751237, learning_rate=0.13135243813665703, max_depth=3, n_estimators=165, subsample=0.6336559859980195; total time=   8.1s
# [CV] END colsample_bytree=0.6646514856378455, learning_rate=0.2795662565581238, max_depth=6, n_estimators=161, subsample=0.6405886171464128; total time=  11.4s
# [CV] END colsample_bytree=0.8654007076432223, learning_rate=0.011518475153865606, max_depth=8, n_estimators=131, subsample=0.7942455014344907; total time=  14.9s
# [CV] END colsample_bytree=0.7301598792637071, learning_rate=0.23394742153540724, max_depth=9, n_estimators=194, subsample=0.7232243167409557; total time=  19.0s
# [CV] END colsample_bytree=0.749816047538945, learning_rate=0.2952142919229748, max_depth=5, n_estimators=121, subsample=0.8394633936788146; total time=   7.6s
# [CV] END colsample_bytree=0.6624074561769746, learning_rate=0.05679835610086079, max_depth=5, n_estimators=137, subsample=0.7334834444556088; total time=  10.1s
# [CV] END colsample_bytree=0.8446612641953124, learning_rate=0.012119891565915222, max_depth=3, n_estimators=98, subsample=0.8099098641033556; total time=   5.4s
# [CV] END colsample_bytree=0.8446612641953124, learning_rate=0.012119891565915222, max_depth=3, n_estimators=98, subsample=0.8099098641033556; total time=   5.4s
# [CV] END colsample_bytree=0.9140703845572055, learning_rate=0.06990213464750791, max_depth=9, n_estimators=113, subsample=0.786705157299192; total time=  14.2s
# [CV] END colsample_bytree=0.9862528132298237, learning_rate=0.2525192044349383, max_depth=3, n_estimators=139, subsample=0.6390688456025535; total time=   7.4s
# [CV] END colsample_bytree=0.8736932106048627, learning_rate=0.1420457481218804, max_depth=9, n_estimators=57, subsample=0.6137554084460873; total time=   7.1s
# [CV] END colsample_bytree=0.6831766651472755, learning_rate=0.18031009834599745, max_depth=7, n_estimators=195, subsample=0.9100531293444458; total time=  15.1s
# [CV] END colsample_bytree=0.6353970008207678, learning_rate=0.06879485872574355, max_depth=3, n_estimators=89, subsample=0.9378135394712606; total time=   4.8s
# [CV] END colsample_bytree=0.6353970008207678, learning_rate=0.06879485872574355, max_depth=3, n_estimators=89, subsample=0.9378135394712606; total time=   5.6s
# [CV] END colsample_bytree=0.8989280440549523, learning_rate=0.17190763971672393, max_depth=4, n_estimators=173, subsample=0.7103996728090174; total time=   9.4s
# [CV] END colsample_bytree=0.718509402281633, learning_rate=0.05958008171890075, max_depth=3, n_estimators=120, subsample=0.7693605922825478; total time=   6.4s
# [CV] END colsample_bytree=0.88453678109946, learning_rate=0.2470526621593617, max_depth=5, n_estimators=54, subsample=0.9705203514053395; total time=   3.7s
# [CV] END colsample_bytree=0.88453678109946, learning_rate=0.2470526621593617, max_depth=5, n_estimators=54, subsample=0.9705203514053395; total time=   3.8s
# [CV] END colsample_bytree=0.88453678109946, learning_rate=0.2470526621593617, max_depth=5, n_estimators=54, subsample=0.9705203514053395; total time=   3.7s
# [CV] END colsample_bytree=0.8604308102007778, learning_rate=0.28448790266313423, max_depth=3, n_estimators=121, subsample=0.7797802696552814; total time=   6.5s
# [CV] END colsample_bytree=0.6381640465961645, learning_rate=0.1212454756594799, max_depth=8, n_estimators=86, subsample=0.8918424713352255; total time=   8.5s
# [CV] END colsample_bytree=0.8550229885420852, learning_rate=0.27616382277289797, max_depth=3, n_estimators=150, subsample=0.9886848381556415; total time=   7.0s
# [CV] END colsample_bytree=0.9395655297064336, learning_rate=0.22651885634946198, max_depth=9, n_estimators=191, subsample=0.7975182385457563; total time=  22.5s
# [CV] END colsample_bytree=0.6125716742746937, learning_rate=0.20092312337913412, max_depth=6, n_estimators=145, subsample=0.878206434570451; total time=   9.9s
# [CV] END colsample_bytree=0.6307919639315172, learning_rate=0.0969254358741304, max_depth=8, n_estimators=77, subsample=0.9718790609370292; total time=   7.9s
# [CV] END colsample_bytree=0.9232481518257668, learning_rate=0.20002112695312704, max_depth=8, n_estimators=77, subsample=0.9214688307596458; total time=   8.4s
# [CV] END colsample_bytree=0.6746280235544143, learning_rate=0.2777676995469933, max_depth=5, n_estimators=177, subsample=0.922976062065625; total time=  10.3s
# [CV] END colsample_bytree=0.7708431154505025, learning_rate=0.25540442977674793, max_depth=3, n_estimators=52, subsample=0.6027808522124762; total time=   2.8s
# [CV] END colsample_bytree=0.7708431154505025, learning_rate=0.25540442977674793, max_depth=3, n_estimators=52, subsample=0.6027808522124762; total time=   2.8s
# [CV] END colsample_bytree=0.8042989210310263, learning_rate=0.1352233009446337, max_depth=7, n_estimators=100, subsample=0.7077649335194086; total time=   8.5s
# [CV] END colsample_bytree=0.6976502088991097, learning_rate=0.06048731265187917, max_depth=3, n_estimators=162, subsample=0.6259568988435926; total time=   8.8s
# [CV] END colsample_bytree=0.7015661655737379, learning_rate=0.08406281885158035, max_depth=9, n_estimators=179, subsample=0.8849082359697769; total time=  20.0s
# [CV] END colsample_bytree=0.7644148053272926, learning_rate=0.019915219870164515, max_depth=3, n_estimators=178, subsample=0.695824756266789; total time=  10.1s
# [CV] END colsample_bytree=0.6579579488364892, learning_rate=0.1568358280832689, max_depth=8, n_estimators=117, subsample=0.632341330533086; total time=  11.2s
# [CV] END colsample_bytree=0.9933692563579372, learning_rate=0.12964733273336593, max_depth=9, n_estimators=193, subsample=0.9341209982356952; total time=  22.8s
# [CV] END colsample_bytree=0.871025744736913, learning_rate=0.014976348678356847, max_depth=5, n_estimators=196, subsample=0.7394663949166917; total time=  13.7s
# [CV] END colsample_bytree=0.8702760468157122, learning_rate=0.23056483577223164, max_depth=4, n_estimators=91, subsample=0.7031766510860622; total time=   5.2s
# [CV] END colsample_bytree=0.8702760468157122, learning_rate=0.23056483577223164, max_depth=4, n_estimators=91, subsample=0.7031766510860622; total time=   5.2s
# [CV] END colsample_bytree=0.9985014799031697, learning_rate=0.2996258053866381, max_depth=7, n_estimators=86, subsample=0.9530545372757359; total time=   7.4s
# [CV] END colsample_bytree=0.6754828433365517, learning_rate=0.09366140577765455, max_depth=5, n_estimators=97, subsample=0.9386644568953224; total time=   6.6s
# [CV] END colsample_bytree=0.942529716751237, learning_rate=0.13135243813665703, max_depth=3, n_estimators=165, subsample=0.6336559859980195; total time=   8.2s
# [CV] END colsample_bytree=0.8654007076432223, learning_rate=0.011518475153865606, max_depth=8, n_estimators=131, subsample=0.7942455014344907; total time=  15.2s
# [CV] END colsample_bytree=0.7793696571944989, learning_rate=0.3083372387832462, max_depth=6, n_estimators=117, subsample=0.69489963499872; total time=   8.3s
# [CV] END colsample_bytree=0.7301598792637071, learning_rate=0.23394742153540724, max_depth=9, n_estimators=194, subsample=0.7232243167409557; total time=  20.1s
